# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn treeinterpreter

import pickle
# Out:
# Requirement already satisfied: pandas in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.4.4)
# Requirement already satisfied: matplotlib in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.8.0)
# Requirement already satisfied: treeinterpreter in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\pp4ab\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\pp4ab\AppData\Roaming\Python\Python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\pp4ab\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in C:\Users\pp4ab\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.impute import SimpleImputer

print("Everything imported successfully")
# Out:
# Everything imported successfully
